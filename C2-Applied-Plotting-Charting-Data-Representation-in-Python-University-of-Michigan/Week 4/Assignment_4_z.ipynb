# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = pd.read_csv('./co2.csv',skiprows=3)

# %%
df.set_index('Country Name',inplace=True)

# %%
df.head()
# Out:
#                             Country Code      Indicator Name  Indicator Code  \
# Country Name
# Aruba                                ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Africa Eastern and Southern          AFE  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Afghanistan                          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Africa Western and Central           AFW  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Angola                               AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
#                                       1960          1961           1962  \
# Country Name
# Aruba                         11092.675000   11576.71900   12713.489000
# Africa Eastern and Southern  118545.901306  123758.90333  128093.897815
# Afghanistan                     414.371000     491.37800     689.396000
# Africa Western and Central     8760.463000    9376.51900    9710.216000
# Angola                          550.050000     454.70800    1180.774000
#
# ...

# %%
# Out:
#                            Country Code      Indicator Name  Indicator Code  \
# Country Name
# Africa Western and Central          AFW  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Angola                              AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Albania                             ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Andorra                             AND  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Arab World                          ARB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# ...                                 ...                 ...             ...
# Kosovo                              XKX  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Yemen, Rep.                         YEM  CO2 emissions (kt)  EN.ATM.CO2E.KT
# South Africa                        ZAF  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Zambia                              ZMB  CO2 emissions (kt)  EN.ATM.CO2E.KT
# Zimbabwe                            ZWE  CO2 emissions (kt)  EN.ATM.CO2E.KT
#
# ...
